# %%
import pandas as pd
dataset=pd.read_csv('/content/titanic.csv')

# %%
dataset
# Out:
#      PassengerId  Survived                                             Pclass  \
# 0              1         0                                  , Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         3                             Heikkinen, Miss. Laina
# 3              4         1                                                  1
# 4              5         0                                                  3
# ..           ...       ...                                                ...
# 886          887         0                                                  2
# 887          888         1                                                  1
# 888          889         0                                                  3
# 889          890         1                                                  1
# 890          891         0                                                  3
#
# ...

# %% [markdown]
# Shape gives the no of rows and no of columns in the dataset

# %%
dataset.shape
# Out:
# (891, 12)

# %% [markdown]
# Is null is used to check null values present in datset
#
# > Add blockquote

# %%
dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False    True
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# It gives null values as NaN

# %%
A=dataset.isnull().sum()
dataset.head()
# Out:
#    PassengerId  Survived                                             Pclass  \
# 0            1         0                                  , Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         3                             Heikkinen, Miss. Laina
# 3            4         1                                                  1
# 4            5         0                                                  3
#
#                                            Name     Sex   Age  \
# 0                                          male      22   1.0
# 1                                        female      38   1.0
# 2                                            26       0   0.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                      Allen, Mr. William Henry    male   0.0
#
#               SibSp      Parch   Ticket  Fare Cabin Embarked
# 0                 0  A/5 21171     7.25   NaN     S      NaN
# ...

# %% [markdown]
# Here fillna is used for filling in the missing values

# %%
dataset.fillna('svpcet')
# Out:
#      PassengerId  Survived                                             Pclass  \
# 0              1         0                                  , Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         3                             Heikkinen, Miss. Laina
# 3              4         1                                                  1
# 4              5         0                                                  3
# ..           ...       ...                                                ...
# 886          887         0                                                  2
# 887          888         1                                                  1
# 888          889         0                                                  3
# 889          890         1                                                  1
# 890          891         0                                                  3
#
# ...

# %%
dataset.Age=dataset.Age.fillna((dataset.Age).mean())

# %%
dataset.fillna(method='pad')
# Out:
# <ipython-input-13-b659c29b98eb>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method='pad')
#      PassengerId  Survived                                             Pclass  \
# 0              1         0                                  , Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         3                             Heikkinen, Miss. Laina
# 3              4         1                                                  1
# 4              5         0                                                  3
# ..           ...       ...                                                ...
# 886          887         0                                                  2
# 887          888         1                                                  1
# ...

# %% [markdown]
# ffill is used for filling the upper value from the nulll value

# %%
a.fillna(method='ffill')
# Out:
# <ipython-input-16-406d76989633>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   a.fillna(method='ffill')
#      PassengerId  Survived                                             Pclass  \
# 0              1         0                                  , Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         3                             Heikkinen, Miss. Laina
# 3              4         1                                                  1
# 4              5         0                                                  3
# ..           ...       ...                                                ...
# 886          887         0                                                  2
# 887          888         1                                                  1
# ...

# %% [markdown]
# dropna drops the row which are having null values in it

# %%
f=dataset.dropna()
f
# Out:
#      PassengerId  Survived Pclass  \
# 3              4         1      1
# 6              7         0      1
# 10            11         1      3
# 11            12         1      1
# 21            22         1      2
# ..           ...       ...    ...
# 871          872         1      1
# 872          873         0      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                  Name     Sex   Age SibSp  \
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 6                             McCarthy, Mr. Timothy J    male  54.0     0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0     1
# 11                           Bonnell, Miss. Elizabeth  female  58.0     0
# 21                              Beesley, Mr. Lawrence    male  34.0     0
# ..                                                ...     ...   ...   ...
# ...

# %% [markdown]
# duplicated tell that where are duplicate values present

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# it tells specific in ticket columns how many are duplicate values

# %%
a.duplicated('Ticket')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Length: 891, dtype: bool
